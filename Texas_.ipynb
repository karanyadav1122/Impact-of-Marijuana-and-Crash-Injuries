# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('C:/Users/karan/Texas_19_20_21 (3).csv')
# Out:
# C:\Users\karan\AppData\Local\Temp\ipykernel_12400\3615861721.py:1: DtypeWarning: Columns (25,40,50,52,86,90,97,160) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('C:/Users/karan/Texas_19_20_21 (3).csv')

# %%
data = data.dropna(subset=['Latitude','Longitude','Prsn_Age','Street_Name','Rpt_Block_Num','Investigat_Notify_Meth',
                         'Nbr_Of_Lane','Median_Width','Rural_Urban_Type_ID' ])

# %%
data.shape
# Out:
# (505677, 180)

# %%
pd.set_option('display.max_rows', None)

# %%
print(t)
# Out:
# Crash_ID                             0
# Prsn_Type_ID                         0
# Prsn_Age                        225325
# Prsn_Ethnicity_ID                 8027
# Prsn_Gndr_ID                         0
# Crash_Fatal_Fl                       0
# Cmv_Involv_Fl                        0
# Schl_Bus_Fl                          0
# Rr_Relat_Fl                          0
# Medical_Advisory_Fl                  0
# Amend_Supp_Fl                        0
# Active_School_Zone_Fl                0
# Crash_Date                           0
# Crash_Time                           0
# Case_ID                         129211
# Local_Use                      1034802
# Rpt_CRIS_Cnty_ID                     0
# FIPS_Code                            0
# County_Name                          0
# Rpt_City_ID                          0
# Rpt_Outside_City_Limit_Fl            0
# Thousand_Damage_Fl                   0
# Rpt_Latitude                   1188566
# Rpt_Longitude                  1188566
# ...

# %%
cols = ['Latitude','Longitude','Prsn_Age','Street_Name','Rpt_Block_Num','Investigat_Notify_Meth',
                         'Nbr_Of_Lane','Median_Width','Rural_Urban_Type_ID','Rpt_Rdwy_Sys_ID']

# %%
d = data[cols]

# %%
d
# Out:
#           Latitude   Longitude  Prsn_Age Street_Name Rpt_Block_Num  \
# 6        30.660683  -93.893876      48.0      US0096           100
# 7        32.791600  -96.737721      44.0      IH0030          6200
# 10       32.593594  -96.822456      37.0     IH0035E          1200
# 11       33.585548 -101.939751      53.0      FM2528          1000
# 13       29.529787  -95.110649      32.0      SHNASA           100
# ...            ...         ...       ...         ...           ...
# 1492828  29.731054  -99.063342      38.0      SH0016           700
# 1492829  29.731734  -99.082254      52.0      SH0016           100
# 1492830  27.613194  -99.522126      66.0      FM1472         13600
# 1492837  29.775023  -95.260266      18.0      IH0010         21000
# 1492838  30.221441  -95.566707      35.0      FM1488          6745
#
#         Investigat_Notify_Meth  Nbr_Of_Lane  Median_Width  \
# 6             SAW WRECK HAPPEN          4.0           0.0
# ...

# %%
r = d.drop_duplicates(keep='first')

# %%
r.isna().sum().sum()
# Out:
# 0

# %%
r.columns
# Out:
# Index(['Latitude', 'Longitude', 'Prsn_Age', 'Street_Name', 'Rpt_Block_Num',
#        'Investigat_Notify_Meth', 'Nbr_Of_Lane', 'Median_Width',
#        'Rural_Urban_Type_ID', 'Rpt_Rdwy_Sys_ID'],
#       dtype='object')

# %%
r.columns
# Out:
# Index(['Latitude', 'Longitude', 'Prsn_Age', 'Street_Name', 'Rpt_Block_Num',
#        'Investigat_Notify_Meth', 'Nbr_Of_Lane', 'Median_Width',
#        'Rural_Urban_Type_ID', 'Rpt_Rdwy_Sys_ID'],
#       dtype='object')

# %%
r.to_csv('TEXAS_RAW_19_20_21.csv',index= False)
