# %%
import numpy as np
import pandas as pd

# %%
colorado = pd.read_csv('C:/Users/karan/colorado_final_merged.csv')
# Out:
# C:\Users\karan\AppData\Local\Temp\ipykernel_18180\3015559863.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   colorado = pd.read_csv('C:/Users/karan/colorado_final_merged.csv')

# %%
 for i in colorado.columns:
        print(i)
# Out:
# ROAD_CLASS
# DATE
# TIME
# INTERSECTION
# CONTOUR
# SURFACE
# LIGHTING
# WEATHER
# HUMAN_FACTOR
# INTOXICATION
# AGE
# GENDER
# COUNTY_FIPS
# COUNTY
# LATITUDE
# LONGITUDE
# INJURY_COUNT
# INJURY_OUTCOME
# Crash_ID
# BUFF_DIST
# ORIG_FID
# Shape_Length
# Shape_Area
# WEATHER_DESC
# BLOWING SAND/SNOW
# CLEAR
# CLOUDY
# FOG
# OTHER_WEATHER
# RAIN
# SEVERE CROSSWINDS
# SLEET/HAIL
# SNOW_WEATHER
# LIGHTING_DESC
# DARK-LIGHTED
# DARK-NOT LIGHTED
# DAWN
# DAYLIGHT
# DUSK
# SURF_DESC
# DIRT
# DRY
# ICE
# SLUSH
# SNOW_SURF
# UNKNOWN_SURF
# WET
# INTOXICATION_DESC
# ALCOHOL
# ALCOHOL, DRUG
# DRUG
# MEDICINAL
# MARIJUANA
# NO INTOXICATION
# INTERSECTION_DESC
# NO_INTERSECTION
# YES_INTERSECTION
# ROAD_TYPE_DESC
# CITY STREET
# COUNTY ROAD
# INTERSTATE
# OTHER ROADS
# US & STATE HIGHWAY
# HUMAN_FACTOR_DESC
# IMPAIRMENT
# INATTENTION
# KNOWN_HUMAN_FACTOR
# LANE_CHNG
# NO_FAULT
# SPEEDING
# TAILGATING
# TECH_PARK
# TURNING
# UNKNOWN_HUMAN_FACTOR
# UNSAFE_BACKING
# VIOLATION
# AGE_BAND
# AGE 1-21
# ...

# %%
texas = pd.read_csv('C:/Users/karan/texas_comb.csv')

# %%
for i in texas.columns:
    print(i)
# Out:
# Crash_ID
# AGE
# GENDER
# DATE
# TIME
# COUNTY_FIPS
# COUNTY
# INTERSECTION
# WEATHER
# LIGHTING
# SURFACE
# HUMAN_FACTOR
# ROAD_CLASS
# LATITUDE
# LONGITUDE
# MEDIANWIDTH
# LANES
# ROADWIDTH
# AADT
# INJURY_OUTCOME
# INJURY_COUNT
# INTOXICATION
# BUFF_DIST
# ORIG_FID
# Shape_Length
# Shape_Area
# AGE_BAND
# AGE 1-21
# AGE 22-30
# AGE 31-65
# AGE 66 and above
# Unknown Age
# GENDER_DESC
# FEMALE
# MALE
# UNKNOWN_GENDER
# INTERSECTION_DESC
# NO_INTERSECTION
# YES_INTERSECTION
# WEATHER_DESC
# BLOWING SAND/SNOW
# CLEAR
# CLOUDY
# FOG
# OTHER_WEATHER
# RAIN
# SEVERE CROSSWINDS
# SLEET/HAIL
# SNOW_WEATHER
# UNKNOWN_WEATHER
# LIGHTING_DESC
# DARK-LIGHTED
# DARK-NOT LIGHTED
# DARK-UNKNOWN LIGHTING
# DAWN
# DAYLIGHT
# DUSK
# OTHER_LIGHT
# UNKNOWN_LIGHT
# SURF_DESC
# DIRT
# DRY
# ICE
# OTHER_SURF
# SLUSH
# SNOW_SURF
# STANDING_WATER
# UNKNOWN_SURF
# WET
# HUMAN_FACTOR_DESC
# IMPAIRMENT
# INATTENTION
# KNOWN_HUMAN_FACTOR
# LANE_CHNG
# NO_FAULT
# SPEEDING
# TAILGATING
# TECH_PARK
# TURNING
# ...

# %%
colorado.columns.get_loc('SNOW_SURF')
# Out:
# 44

# %%
colorado.insert(33,'UNKNOWN_WEATHER',0)

# %%
colorado.insert(37,'DARK-UNKNOWN LIGHTING',0)

# %%
colorado.insert(41,'OTHER_LIGHT',0)

# %%
colorado.insert(42,'UNKNOWN_LIGHT',0)

# %%
colorado.insert(47,'OTHER_SURF',0)

# %%
colorado.insert(50,'STANDING_WATER',0)

# %%
colorado.columns.get_loc('TOLL BRIDGES')
# Out:
# 69

# %%
colorado.insert(66,'FARM TO MARKET',0)

# %%
colorado.insert(69,'TOLL BRIDGES',0)

# %%
colorado.insert(70,'TOLLWAY',0)

# %%
colm = ['Crash_ID','DATE','TIME','COUNTY_FIPS','COUNTY','LATITUDE','LONGITUDE',
          'INJURY_COUNT_SUM','FEMALE','MALE','UNKNOWN_GENDER','NO_INTERSECTION',
'YES_INTERSECTION','BLOWING SAND/SNOW',
'CLEAR',
'CLOUDY',
'FOG',
'OTHER_WEATHER',
'RAIN',
'SEVERE CROSSWINDS',
'SLEET/HAIL',
'SNOW_WEATHER',
'UNKNOWN_WEATHER',
           'DARK-LIGHTED',
'DARK-NOT LIGHTED',
'DARK-UNKNOWN LIGHTING',
'DAWN',
'DAYLIGHT',
'DUSK',
'OTHER_LIGHT',
'UNKNOWN_LIGHT','DIRT',
'DRY',
'ICE',
'OTHER_SURF',
'SLUSH',
'SNOW_SURF',
'STANDING_WATER',
'UNKNOWN_SURF',
'WET','ALCOHOL',
'ALCOHOL, DRUG',
'DRUG',
'MEDICINAL',
'MARIJUANA',
'NO INTOXICATION','CITY STREET',
'COUNTY ROAD',
'FARM TO MARKET',
'INTERSTATE',
'OTHER ROADS',
'TOLL BRIDGES',
'TOLLWAY',
'US & STATE HIGHWAY','NO_INJURY',
'YES_INJURY','IMPAIRMENT',
'INATTENTION',
'KNOWN_HUMAN_FACTOR',
'LANE_CHNG',
'NO_FAULT',
'SPEEDING',
'TAILGATING',
'TECH_PARK',
'TURNING',
'UNKNOWN_HUMAN_FACTOR',
'UNSAFE_BACKING',
'VIOLATION','AGE 1-21',
'AGE 22-30',
'AGE 31-65',
'AGE 66 and above',
'Unknown Age','YEAR_CAT',
'YEAR_2019',
'YEAR_2020',
'YEAR_2021'
          ]

# %%
texas_new = texas[colm]

# %%
colorado_new = colorado[colm]

# %%
texas_colorado_comb = pd.concat([texas_new,colorado_new],axis=0)

# %%
texas_colorado_comb.to_csv('texas_colorado_comb.csv',index= False)

# %%
v = pd.read_csv('C:/Users/karan/texas_colorado_comb.csv')
# Out:
# C:\Users\karan\AppData\Local\Temp\ipykernel_18180\678806664.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   v = pd.read_csv('C:/Users/karan/texas_colorado_comb.csv')

# %%
v
# Out:
#         Crash_ID        DATE      TIME  COUNTY_FIPS     COUNTY   LATITUDE  \
# 0       15585669   2/10/2019   4:50 PM        48141    El Paso  31.726117
# 1       16473665   6/15/2019  11:00 AM        48241     Jasper  30.660683
# 2       16585839   1/26/2019  12:40 PM        48113     Dallas  32.791600
# 3       16824697    1/1/2019   4:53 AM        48113     Dallas  32.593594
# 4       16824710    1/1/2019   2:57 AM        48303    Lubbock  33.585548
# ...          ...         ...       ...          ...        ...        ...
# 501521  10242114  12/31/2021  23:22:00         8013    BOULDER  39.972348
# 501522  10242115  12/31/2021  23:23:00         8117     SUMMIT  39.605230
# 501523  10242116  12/31/2021  23:39:00         8059  JEFFERSON  39.695930
# 501524  10242117  12/31/2021  23:41:00         8123       WELD  40.422650
# 501525  10242118  12/31/2021  23:43:00         8001      ADAMS  39.830140
#
#          LONGITUDE  INJURY_COUNT_SUM     FEMALE       MALE  ...  VIOLATION  \
# ...
