# %%
import numpy as np
import pandas as pd

# %%
tcoris = pd.read_csv('C:/Users/karan/TCORIS.csv')
# Out:
# C:\Users\karan\AppData\Local\Temp\ipykernel_4872\412282950.py:1: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   tcoris = pd.read_csv('C:/Users/karan/TCORIS.csv')

# %%
for i in tcoris.columns:
    print(i,'\n')
# Out:
# ROUTE
#
# REFPT
#
# ENDREFPT
#
# RUNLENGTH_FROM
#
# RUNLENGTH_TO
#
# LENGTH_
#
# UPDATEYR
#
# FIPSCITY
#
# FIPSCOUNTY
#
# POPULATION
#
# URBAN
#
# FUNCCLASSID
#
# ROUTESIGN
#
# ROUTESIGNQUAL
#
# GOVLEVEL
#
# SPECIALSYS
#
# TRKRESTRICT
#
# TOLL
#
# ACCESS_
#
# ADMINCLASS
#
# FORESTROUTE
#
# NHSDESIG
#
# BYWAY_NAME
#
# COMMDISTID
#
# REGION
#
# FEDHSEDISTID
#
# STESENDISTID
#
# STEHSEDISTID
#
# LANDOWNER
#
# TPRID
#
# MPOID
#
# MAINTSECTION
#
# PATROL
#
# SECIRI
#
# SECLTRUT
#
# SECRTRUT
#
# SECIRII
#
# SECIRIDATE
#
# SECRUTI
#
# SECRDL
#
# SECDLCLASS
#
# SECRUTTING
#
# SECFAULTING
#
# SECFATIGUECRACK
#
# SECTRANSCRACK
#
# PRIIRI
#
# PRILTRUT
#
# PRIRTRUT
#
# PRIIRII
#
# PRIIRIDATE
#
# PRIRUTI
#
# PRIRDL
#
# PRIDLCLASS
#
# PRIRUTTING
#
# PRIFAULTING
#
# PRIFATIGUECRACK
#
# PRITRANSCRACK
#
# SPEEDLIM
#
# AADT
#
# AADTYR
#
# AADTDERIV
#
# AADTSINGLE
#
# AADTCOMB
#
# AADTTRUCKS
#
# DHTRK
#
# OFFPKTRK
#
# YR20FACTOR
#
# DHV
#
# DD
#
# ROUTECAPAC
#
# EDLA
#
# VCRATIO
#
# VCRATIO20
#
# ...

# %%
tcoris_sys = pd.read_csv('C:/Users/karan/TCORIS_OFFSYSTEM.csv')
# Out:
# C:\Users\karan\AppData\Local\Temp\ipykernel_4872\952530037.py:1: DtypeWarning: Columns (44,78,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   tcoris_sys = pd.read_csv('C:/Users/karan/TCORIS_OFFSYSTEM.csv')

# %%
tcoris_sys['THRULNQTY'].unique()
# Out:
# array([4, 2, 5, 1, 3, 6, 8, 7], dtype=int64)

# %%
for i in tcoris_sys.columns:
    print(i,'\n')
# Out:
# LRSROUTE
#
# RUNLENGTH_FROM
#
# RUNLENGTH_TO
#
# LENGTH_
#
# ROUTENAME
#
# FROMDESC
#
# TODESC
#
# GISID
#
# FundID
#
# UPDATEYR
#
# FIPSCOUNTY
#
# FUNCCLASSID
#
# GOVLEVEL
#
# ADMINCLASS
#
# NHSDESIG
#
# SPECIALSYS
#
# TRKRESTRICT
#
# POPULATION
#
# URBAN
#
# UABName
#
# REGION
#
# TPRID
#
# ACCESS_
#
# OPERATION
#
# SURF
#
# SURFWD
#
# THRULNQTY
#
# THRULNWD
#
# COUNTSTATIONID
#
# AADT
#
# DVMT
#
# AADTSINGLE
#
# AADTCOMB
#
# COUNTYEAR
#
# AADTYR
#
# AADTDERIV
#
# PSR
#
# IRI
#
# IRIDATE
#
# HUTF_INSPYR
#
# HUTF_PROJYR
#
# BUILTYR
#
# YRREHAB
#
# TREATMENTDEPTH
#
# FORESTROUTE
#
# JURSPLIT
#
# FIPS
#
# ROUTE
#
# SEGMID
#
# FROMFEATURE
#
# SEGMDIR
#
# TOFEATURE
#
# SEGPREFIX
#
# GUID
#
# Shape_Length
#
# OBJECTID
#
# Join_Count
#
# TARGET_FID
#
# ROUTE_1
#
# REFPT
#
# ENDREFPT
#
# RUNLENGTH_FROM_1
#
# RUNLENGTH_TO_1
#
# LENGTH1
#
# UPDATEYR_1
#
# FIPSCITY
#
# FIPSCOUNTY_1
#
# POPULATION_1
#
# URBAN_1
#
# FUNCCLASSID_1
#
# ROUTESIGN
#
# ROUTESIGNQUAL
#
# GOVLEVEL_1
#
# SPECIALSYS_1
# ...

# %%
tcoris_sys.columns
# Out:
# Index(['LRSROUTE', 'RUNLENGTH_FROM', 'RUNLENGTH_TO', 'LENGTH_', 'ROUTENAME',
#        'FROMDESC', 'TODESC', 'GISID', 'FundID', 'UPDATEYR',
#        ...
#        'MAL', 'MALALIGN', 'MALNQTY', 'BUILTYR_1', 'ISDIVIDED', 'OPERATION_1',
#        'HPMSID', 'FROMDESC_1', 'TODESC_1', 'Shape_Length_1'],
#       dtype='object', length=185)

# %%
common_columns = tcoris.columns.intersection(tcoris_sys.columns)

# %%
for i in common_columns:
    print(i,'\n')
# Out:
# ROUTE
#
# REFPT
#
# ENDREFPT
#
# RUNLENGTH_FROM
#
# RUNLENGTH_TO
#
# LENGTH_
#
# UPDATEYR
#
# FIPSCITY
#
# FIPSCOUNTY
#
# POPULATION
#
# URBAN
#
# FUNCCLASSID
#
# ROUTESIGN
#
# ROUTESIGNQUAL
#
# GOVLEVEL
#
# SPECIALSYS
#
# TRKRESTRICT
#
# TOLL
#
# ACCESS_
#
# ADMINCLASS
#
# FORESTROUTE
#
# NHSDESIG
#
# BYWAY_NAME
#
# COMMDISTID
#
# REGION
#
# FEDHSEDISTID
#
# STESENDISTID
#
# STEHSEDISTID
#
# LANDOWNER
#
# TPRID
#
# MPOID
#
# MAINTSECTION
#
# PATROL
#
# SECIRI
#
# SECLTRUT
#
# SECRTRUT
#
# SECIRII
#
# SECIRIDATE
#
# SECRUTI
#
# SECRDL
#
# SECDLCLASS
#
# SECRUTTING
#
# SECFAULTING
#
# SECFATIGUECRACK
#
# SECTRANSCRACK
#
# PRIIRI
#
# PRILTRUT
#
# PRIRTRUT
#
# PRIIRII
#
# PRIIRIDATE
#
# PRIRUTI
#
# PRIRDL
#
# PRIDLCLASS
#
# PRIRUTTING
#
# PRIFAULTING
#
# PRIFATIGUECRACK
#
# PRITRANSCRACK
#
# SPEEDLIM
#
# AADT
#
# AADTYR
#
# AADTDERIV
#
# AADTSINGLE
#
# AADTCOMB
#
# AADTTRUCKS
#
# DHTRK
#
# OFFPKTRK
#
# YR20FACTOR
#
# DHV
#
# DD
#
# ROUTECAPAC
#
# EDLA
#
# VCRATIO
#
# VCRATIO20
#
# ...

# %%
tcoris_1 = tcoris[['ROUTE','REFPT','ENDREFPT','RUNLENGTH_TO','RUNLENGTH_FROM','LENGTH_','FIPSCITY',
                   'FIPSCOUNTY','FUNCCLASSID','ROUTESIGN','SPEEDLIM','AADT',
                  'MEDIANWD','THRULNQTY','ROWWD','Shape_Length']]

# %%
len(['ROUTE','REFPT','ENDREFPT','RUNLENGTH_TO','RUNLENGTH_FROM','LENGTH_','FIPSCITY',
                   'FIPSCOUNTY','FUNCCLASSID','ROUTESIGN','SPEEDLIM','AADT',
                  'MEDIANWD','THRULNQTY','ROWWD','Shape_Length'])
# Out:
# 16

# %%
tcoris_sys_1 = tcoris_sys[['ROUTE','REFPT','ENDREFPT','RUNLENGTH_TO','RUNLENGTH_FROM','LENGTH_','FIPSCITY',
                   'FIPSCOUNTY','FUNCCLASSID','ROUTESIGN','SPEEDLIM','AADT',
                  'MEDIANWD','THRULNQTY','ROWWD','Shape_Length']]

# %%
tcoris_1.shape
# Out:
# (142660, 16)

# %%
tcoris_sys_1.shape
# Out:
# (223810, 16)

# %%
tcor_comb = pd.concat([tcoris_1,tcoris_sys_1],axis= 0)

# %%
tcor_comb
# Out:
#        ROUTE    REFPT  ENDREFPT  RUNLENGTH_TO  RUNLENGTH_FROM  LENGTH_  \
# 0       006E  151.835   151.923         2.200           2.113    0.087
# 1       006J  426.056   426.155        54.673          54.573    0.100
# 2       006G  264.000   264.017         6.937           6.921    0.016
# 3       006E  171.029   171.079        21.298          21.248    0.050
# 4       006A   13.387    13.487         2.400           2.300    0.100
# ...      ...      ...       ...           ...             ...      ...
# 223805     L      NaN       NaN         3.160           0.000    3.160
# 223806    NN      NaN       NaN         7.890           6.880    1.010
# 223807     H      NaN       NaN        13.170          12.150    1.020
# 223808     X      NaN       NaN         0.840           0.000    0.840
# 223809     Z      NaN       NaN        14.660          12.730    1.930
#
#         FIPSCITY  FIPSCOUNTY  FUNCCLASSID  ROUTESIGN  SPEEDLIM     AADT  \
# ...

# %%
tcor_comb.isnull().sum()
# Out:
# ROUTE                  0
# REFPT             213931
# ENDREFPT          213931
# RUNLENGTH_TO           0
# RUNLENGTH_FROM         0
# LENGTH_                0
# FIPSCITY          333453
# FIPSCOUNTY             0
# FUNCCLASSID            0
# ROUTESIGN         213931
# SPEEDLIM          213931
# AADT              186497
# MEDIANWD          213931
# THRULNQTY              0
# ROWWD             213931
# Shape_Length           0
# dtype: int64

# %%
tcor_comb.columns
# Out:
# Index(['ROUTE', 'REFPT', 'ENDREFPT', 'RUNLENGTH_TO', 'RUNLENGTH_FROM',
#        'LENGTH_', 'FIPSCITY', 'FIPSCOUNTY', 'FUNCCLASSID', 'ROUTESIGN',
#        'SPEEDLIM', 'AADT', 'MEDIANWD', 'THRULNQTY', 'ROWWD', 'Shape_Length'],
#       dtype='object')

# %%
tcor_comb_1 = tcor_comb.copy()

# %%
tcor_comb_1.dropna(inplace=True)

# %%
tcor_comb_1
# Out:
#               ROUTE    REFPT  ENDREFPT  RUNLENGTH_TO  RUNLENGTH_FROM  LENGTH_  \
# 3              006E  171.029   171.079        21.298          21.248    0.050
# 6              006J  404.920   404.972        33.534          33.473    0.061
# 7              006C   43.237    43.269         5.779           5.751    0.028
# 8              006D  105.977   105.987        13.710          13.700    0.010
# 18             006I  344.712   344.716         1.100           1.095    0.005
# ...             ...      ...       ...           ...             ...      ...
# 220144  1ST      ST  147.046   147.064         6.309           3.249    3.060
# 220684           19   16.392    16.417         1.260           0.750    0.510
# 221308  COUNTYLINRD   59.479    59.485         0.470           0.200    0.270
# 221439  MAIN     ST  250.189   250.201         0.330           0.200    0.130
# 222625  CR       53  119.178   119.203         0.940           0.000    0.940
#
# ...

# %%
t_1= tcor_comb[['ROUTE','REFPT', 'ENDREFPT','RUNLENGTH_TO','RUNLENGTH_FROM','LENGTH_',
                   'FIPSCOUNTY','FUNCCLASSID','THRULNQTY','Shape_Length']]

# %%
t_1
# Out:
#        ROUTE    REFPT  ENDREFPT  RUNLENGTH_TO  RUNLENGTH_FROM  LENGTH_  \
# 0       006E  151.835   151.923         2.200           2.113    0.087
# 1       006J  426.056   426.155        54.673          54.573    0.100
# 2       006G  264.000   264.017         6.937           6.921    0.016
# 3       006E  171.029   171.079        21.298          21.248    0.050
# 4       006A   13.387    13.487         2.400           2.300    0.100
# ...      ...      ...       ...           ...             ...      ...
# 223805     L      NaN       NaN         3.160           0.000    3.160
# 223806    NN      NaN       NaN         7.890           6.880    1.010
# 223807     H      NaN       NaN        13.170          12.150    1.020
# 223808     X      NaN       NaN         0.840           0.000    0.840
# 223809     Z      NaN       NaN        14.660          12.730    1.930
#
#         FIPSCOUNTY  FUNCCLASSID  THRULNQTY  Shape_Length
# 0               37            5          2    139.506948
# ...

# %%
t_1.to_csv('tcoris_edited_1.csv',index= False)

# %%
colo=   pd.read_csv('C:/Users/karan/colorado_dummy.csv')
# Out:
# C:\Users\karan\AppData\Local\Temp\ipykernel_4872\1510924446.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   colo=   pd.read_csv('C:/Users/karan/colorado_dummy.csv')

# %%
colo.columns
# Out:
# Index(['SYSTEM', 'DATE', 'TIME', 'INJURY 00', 'INJURY 01', 'INJURY 02',
#        'INJURY 03', 'INJURY 04', 'INTERSECTION', 'CONTOUR', 'SURFACE',
#        'LIGHTING', 'WEATHER', 'HUMAN_FACTOR', 'INTOXICATION', 'AGE', 'GENDER',
#        'COUNTY_FIPS', 'COUNTY', 'LATITUDE', 'LONGITUDE', 'YEAR',
#        'INJURY_COUNT', 'INJURY_OUTCOME', 'Crash_ID', 'DAYLIGHT', 'DAWN',
#        'DARK_NLIGHT', 'DARK_LIGHTED', 'DUSK', 'RAIN', 'SLEET_HAIL', 'SNOW',
#        'FOG', 'SAND_SNOW', 'CROSSWIND', 'OTHER_WEATHER', 'CLEAR', 'CLOUDY',
#        'UNK_SURF', 'DRY_SURF', 'WET_SURF', 'SLUSH_SURF', 'ICE_SURF',
#        'SNOW_SURF', 'DIRT_SURF', 'SPEEDING', 'INATTENTION', 'LANE_CHNG',
#        'TAILGATING', 'VIOLATION', 'UNSAFE_BACKING', 'IMPAIRMENT', 'TURNING',
#        'TECH_PARK', 'NO_FAULT', 'KNW_HMN_FACTOR', 'UNK_HMN_FACTOR'],
#       dtype='object')

# %%
colo.drop(columns= ['INJURY 00', 'INJURY 01', 'INJURY 02',
       'INJURY 03', 'INJURY 04'],inplace= True)

# %%
colo.to_csv('colorado_dummy_1.csv',index= False)

# %%
t_1.columns
# Out:
# Index(['ROUTE', 'RUNLENGTH_TO', 'RUNLENGTH_FROM', 'LENGTH_', 'FIPSCOUNTY',
#        'FUNCCLASSID', 'THRULNQTY', 'Shape_Length'],
#       dtype='object')

# %%
colo = pd.read_csv('C:/Users/karan/colorado_basic.csv')
# Out:
# C:\Users\karan\AppData\Local\Temp\ipykernel_4872\1930375745.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   colo = pd.read_csv('C:/Users/karan/colorado_basic.csv')

# %%
colo
# Out:
#                     SYSTEM        DATE      TIME  INJURY 00  INJURY 01  \
# 0              CITY STREET  2019-01-01         0          3          0
# 1              CITY STREET  2019-01-01         0          1          0
# 2               INTERSTATE  2019-01-01        10          1          0
# 3              CITY STREET  2019-01-01        17          1          0
# 4              CITY STREET  2019-01-01        21          0          0
# ...                    ...         ...       ...        ...        ...
# 242114       State Highway  2021-12-31  23:22:00          3          0
# 242115         County Road  2021-12-31  23:23:00          1          0
# 242116  Interstate Highway  2021-12-31  23:39:00          0          2
# 242117       State Highway  2021-12-31  23:41:00          1          0
# 242118       State Highway  2021-12-31  23:43:00          1          0
#
#         INJURY 02  INJURY 03  INJURY 04          INTERSECTION  \
# ...

# %%
color = pd.read_csv('C:/Users/karan/colorado_basic.csv')
# Out:
# C:\Users\karan\AppData\Local\Temp\ipykernel_4872\249567037.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   color = pd.read_csv('C:/Users/karan/colorado_basic.csv')

# %%
color.columns
# Out:
# Index(['SYSTEM', 'DATE', 'TIME', 'INJURY 00', 'INJURY 01', 'INJURY 02',
#        'INJURY 03', 'INJURY 04', 'INTERSECTION', 'CONTOUR', 'SURFACE',
#        'LIGHTING', 'WEATHER', 'HUMAN_FACTOR', 'INTOXICATION', 'AGE', 'GENDER',
#        'COUNTY_FIPS', 'COUNTY', 'LATITUDE', 'LONGITUDE', 'YEAR',
#        'INJURY_COUNT', 'INJURY_OUTCOME', 'Crash_ID'],
#       dtype='object')

# %%
color['SYSTEM'].unique()
# Out:
# array(['CITY STREET', 'INTERSTATE', 'STATE HIGHWAY', 'COUNTY ROAD',
#        'FRONTAGE ROAD', 'State Highway', 'City Street', 'Frontage Road',
#        'Interstate Highway', 'County Road'], dtype=object)

# %%
color
# Out:
#                     SYSTEM        DATE      TIME  INJURY 00  INJURY 01  \
# 0              CITY STREET  2019-01-01         0          3          0
# 1              CITY STREET  2019-01-01         0          1          0
# 2               INTERSTATE  2019-01-01        10          1          0
# 3              CITY STREET  2019-01-01        17          1          0
# 4              CITY STREET  2019-01-01        21          0          0
# ...                    ...         ...       ...        ...        ...
# 242114       State Highway  2021-12-31  23:22:00          3          0
# 242115         County Road  2021-12-31  23:23:00          1          0
# 242116  Interstate Highway  2021-12-31  23:39:00          0          2
# 242117       State Highway  2021-12-31  23:41:00          1          0
# 242118       State Highway  2021-12-31  23:43:00          1          0
#
#         INJURY 02  INJURY 03  INJURY 04          INTERSECTION  \
# ...
