# %%
import numpy as np
import pandas as pd

# %%
t = pd.read_csv('C:/Users/karan/Texas_Final_3.csv')

# %%
t.columns
# Out:
# Index(['Intoxication', 'Crash_ID', 'Age', 'Ethnicity', 'Gender', 'Crash_Date',
#        'Crash_Time', 'FIPS_Code', 'County_Name', 'Damage_1000', 'Speed',
#        'Intersection', 'Weather', 'Lighting', 'EntrRoad', 'RoadType',
#        'RoadAlign', 'Surface', 'Evnt_1', 'HmnFac_1', 'RoadPart', 'RoadClass',
#        'Latitude', 'Longitude', 'Severity', 'Days', 'MedianWidth', 'NmbrLanes',
#        'Roadbed_Width', 'AADT', 'Injury ', 'Tot_Injry_Cnt', 'Death_Cnt',
#        'YEAR', 'Test'],
#       dtype='object')

# %%
t
# Out:
#         Intoxication  Crash_ID  Age  Ethnicity  Gender Crash_Date Crash_Time  \
# 0                 97  15585669   27          0       2  2/10/2019    4:50 PM
# 1                 97  16473665   48          1       1  6/15/2019   11:00 AM
# 2                 97  16585839   44          2       1  1/26/2019   12:40 PM
# 3                 97  16824697   37          3       1   1/1/2019    4:53 AM
# 4                 97  16824710   53          2       1   1/1/2019    2:57 AM
# ...              ...       ...  ...        ...     ...        ...        ...
# 726218            97  19834478   38          1       1  1/29/2021    3:57 PM
# 726219            97  19850863   52          1       1  2/21/2021   12:22 PM
# 726220            97  19906451   66          2       1  8/25/2021    7:32 PM
# 726221            97  20073914   18          1       1  2/23/2021    3:50 AM
# 726222            97  20087367   35          1       1  3/14/2021    5:30 PM
#
# ...

# %%
d = pd.read_csv('C:/Users/karan/CB_BlockGroup.csv')

# %%
d['GEOID'].duplicated().sum()
# Out:
# 0

# %%
d['FIPS_Code'] = (48000+d['COUNTYFP']*2 -1)

# %%
#d = d.drop_duplicates(subset='FIPS_Code')

# %%
t_19 = t[t['YEAR']==2019]
t_20 = t[t['YEAR']==2020]
t_21 = t[t['YEAR']==2021]

# %%
t_19
# Out:
#         Intoxication  Crash_ID  Age  Ethnicity  Gender Crash_Date Crash_Time  \
# 0                 97  15585669   27          0       2  2/10/2019    4:50 PM
# 1                 97  16473665   48          1       1  6/15/2019   11:00 AM
# 2                 97  16585839   44          2       1  1/26/2019   12:40 PM
# 3                 97  16824697   37          3       1   1/1/2019    4:53 AM
# 4                 97  16824710   53          2       1   1/1/2019    2:57 AM
# ...              ...       ...  ...        ...     ...        ...        ...
# 240998            97  19793324   58          2       2  7/20/2019    5:48 PM
# 240999            97  19793325   46          1       2  5/26/2019    6:21 PM
# 241000            97  19793329   21          1       1   4/5/2019    2:48 AM
# 241001            97  19793333   22          1       1  3/30/2019    9:33 PM
# 241002            97  19845363   32          1       1  3/24/2019    7:30 PM
#
# ...

# %%
d
# Out:
#        STATEFP  COUNTYFP  TRACTCE  BLKGRPCE               AFFGEOID  \
# 0           48       201   341700         3  1500000US482013417003
# 1           48        37    10901         2  1500000US480370109012
# 2           48       427   950204         2  1500000US484279502042
# 3           48       113    13101         2  1500000US481130131012
# 4           48       245     7100         2  1500000US482450071002
# ...        ...       ...      ...       ...                    ...
# 15795       48       439   123400         2  1500000US484391234002
# 15796       48        29   171801         4  1500000US480291718014
# 15797       48        29   150100         4  1500000US480291501004
# 15798       48       141     1900         1  1500000US481410019001
# 15799       48       309     2302         1  1500000US483090023021
#
#               GEOID  NAME LSAD      ALAND    AWATER  FIPS_Code
# 0      482013417003     3   BG   588536.0    2329.0      48401
# ...
