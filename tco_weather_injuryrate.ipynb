# %%
import numpy as np
import pandas as pd

# %%
tco = pd.read_csv('C:/Users/karan/Oklahoma_texas_colorado.csv')

# %%
new = pd.read_csv('C:/Users/karan/tco_pop.csv')

# %%
tco[tco['Crash_ID']==10221660]
# Out:
#       Crash_ID  COUNTY_FIPS    COUNTY  INJURY_COUNT  INJURY_OUTCOME  \
# 1184  10221660         8115  SEDGWICK             0               0
#
#       INJURY_COUNT_SUM  BLOWING SAND/SNOW  CLEAR  CLOUDY  FOG  ...  \
# 1184                 2                0.0  100.0     0.0  0.0  ...
#
#       ALCOHOL, DRUG  DRUG  MARIJUANA  MEDICINAL  NO INTOXICATION  YEAR_CAT  \
# 1184            0.0   0.0        0.0        0.0            100.0       3.0
#
#       YEAR_2019  YEAR_2020  YEAR_2021     STATE
# 1184          0          0          1  Colorado
#
# [1 rows x 47 columns]

# %%
new[new['Crash_ID']==10221660]
# Out:
#      POPULATION  Crash_ID
# 953      2326.0  10221660

# %%
n1 = pd.merge(tco, new,on=['Crash_ID'],how='left')

# %%
n1
# Out:
#       Crash_ID  COUNTY_FIPS      COUNTY  INJURY_COUNT  INJURY_OUTCOME  \
# 0     15585669        48141     El Paso             0               0
# 1     16473665        48241      Jasper             1               1
# 2     16585839        48113      Dallas             1               1
# 3     16824710        48303     Lubbock             2               1
# 4     16824789        48201      Harris             0               0
# ...        ...          ...         ...           ...             ...
# 1180  10212672         8103  RIO BLANCO             2               1
# 1181  10214252         8009        BACA             0               0
# 1182  10214428         8065        LAKE             1               1
# 1183  10215666         8017    CHEYENNE             1               1
# 1184  10221660         8115    SEDGWICK             0               0
#
#       INJURY_COUNT_SUM  BLOWING SAND/SNOW       CLEAR     CLOUDY       FOG  \
# ...

# %%
n1['INJURY_RATE'] = (n1['INJURY_COUNT_SUM']/n1['POPULATION']*100000)

# %%
n1
# Out:
#       Crash_ID  COUNTY_FIPS      COUNTY  INJURY_COUNT  INJURY_OUTCOME  \
# 0     15585669        48141     El Paso             0               0
# 1     16473665        48241      Jasper             1               1
# 2     16585839        48113      Dallas             1               1
# 3     16824710        48303     Lubbock             2               1
# 4     16824789        48201      Harris             0               0
# ...        ...          ...         ...           ...             ...
# 1180  10212672         8103  RIO BLANCO             2               1
# 1181  10214252         8009        BACA             0               0
# 1182  10214428         8065        LAKE             1               1
# 1183  10215666         8017    CHEYENNE             1               1
# 1184  10221660         8115    SEDGWICK             0               0
#
#       INJURY_COUNT_SUM  BLOWING SAND/SNOW       CLEAR     CLOUDY       FOG  \
# ...

# %%
mapp = {
    'Texas':1,
    'Colorado':2,
    'Oklahoma':3
}

# %%
n1['STATE_CAT'] = n1['STATE'].map(mapp)

# %%
n1['STATE_CAT'].unique()
# Out:
# array([1, 3, 2], dtype=int64)

# %%
n2 = n1.copy()

# %%
dummies = pd.get_dummies(n2['STATE'], prefix='STATE')

# %%
dummies
# Out:
#       STATE_Colorado  STATE_Oklahoma  STATE_Texas
# 0                  0               0            1
# 1                  0               0            1
# 2                  0               0            1
# 3                  0               0            1
# 4                  0               0            1
# ...              ...             ...          ...
# 1180               1               0            0
# 1181               1               0            0
# 1182               1               0            0
# 1183               1               0            0
# 1184               1               0            0
#
# [1185 rows x 3 columns]

# %%
v = pd.concat([n2,dummies],axis=1)

# %%
v.to_csv('tco_injury_new.csv',index= False)

# %%
v.isna().sum()
# Out:
# Crash_ID                 0
# COUNTY_FIPS              0
# COUNTY                   0
# INJURY_COUNT             0
# INJURY_OUTCOME           0
# INJURY_COUNT_SUM         0
# BLOWING SAND/SNOW        0
# CLEAR                    0
# CLOUDY                   0
# FOG                      0
# OTHER_WEATHER            0
# RAIN                     0
# SEVERE CROSSWINDS        0
# SLEET/HAIL               0
# SNOW_WEATHER             0
# UNKNOWN_WEATHER          0
# DARK-LIGHTED             0
# DARK-NOT LIGHTED         0
# DARK-UNKNOWN LIGHTING    0
# DAWN                     0
# DAYLIGHT                 0
# DUSK                     0
# OTHER_LIGHT              0
# UNKNOWN_LIGHT            0
# INATTENTION              0
# SPEEDING                 0
# CITY STREET              0
# COUNTY ROAD              0
# FARM TO MARKET           0
# INTERSTATE               0
# OTHER ROADS              0
# TOLL BRIDGES             0
# TOLLWAY                  0
# US & STATE HIGHWAY       0
# ...
