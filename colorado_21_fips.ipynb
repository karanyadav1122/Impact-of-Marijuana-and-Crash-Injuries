# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel('C:/Texas/2021_CRASH_COLORADO_FIPS_INCLUDED.xlsx')

# %%
data.head()
# Out:
#      CUID         SYSTEM       DATE      TIME  Agency Id              City  \
# 0  195435  State Highway 2021-01-01  00:00:00  GLWDSPGPD  GLENWOOD SPRINGS
# 1   40647    County Road 2021-01-01  00:05:00        CSP               NaN
# 2   45365    City Street 2021-01-01  00:17:00       WMPD       WESTMINSTER
# 3   53292    City Street 2021-01-01  00:25:00        DPD            DENVER
# 4   40658    County Road 2021-01-01  00:26:00        CSP               NaN
#
#    County_FIPS     County  Latitude  Longitude  ... TU-1 NM Action   \
# 0         8045   GARFIELD  39.52549 -107.32253  ...             NaN
# 1         8067   LA PLATA       NaN        NaN  ...             NaN
# 2         8059  JEFFERSON  39.82885 -105.04402  ...             NaN
# 3         8031     DENVER  39.70461 -105.01356  ...             NaN
# 4         8059  JEFFERSON       NaN        NaN  ...             NaN
#
#   TU-2 NM Action  TU-1 NM Human Contributing Factor   \
# ...

# %%
data.columns
# Out:
# Index(['CUID', 'SYSTEM', 'DATE', 'TIME', 'Agency Id', 'City', 'County_FIPS',
#        'County', 'Latitude', 'Longitude', 'Location 1', 'Link', 'Location 2',
#        'Location', 'Road Description', 'First HE', 'Second HE', 'Third HE',
#        'Fourth HE', 'MHE', 'Crash Type', 'Wild Animal', 'Number Killed',
#        'Number Injured', 'Injury 00', 'Injury 01', 'Injury 02', 'Injury 03',
#        'Injury 04', 'Total Vehicles', 'Secondary Crash', 'Construction Zone',
#        'School Zone', 'Road Contour Curves', 'Road Contour Grade',
#        'Road Condition', 'Lighting Conditions', 'Weather Condition',
#        'Lane Position', 'TU-1 Direction', 'TU-2 Direction', 'TU-1 Movement',
#        'TU-2 Movement', 'TU-1 Type', 'TU-2 Type', 'TU-1 Hit And Run',
#        'TU-2 Hit And Run', 'TU-1 Driver Action', 'TU-2 Driver Action',
#        'TU-1 Human Contributing Factor', 'TU-2 Human Contributing Factor',
#        'TU-1 Age', 'TU-2 Age', 'TU-1 Sex ', 'TU-2 Sex',
# ...

# %%
useful_cols = ['INJURY 00',
 'INJURY 01',
 'INJURY 02',
 'INJURY 03',
 'INJURY 04','AGE_1','ROAD_DESC','CONTOUR','CONDITION','LIGHTING',
               'WEATHER','SEX_1','SYSTEM','VIOLCODE_1','LOCATION']

# %%
col_rename = {'Road Description':'ROAD_DESC','Road Contour Curves':'CONTOUR','Weather Condition':'WEATHER',
             'Road Condition':'CONDITION','Lighting Conditions':'LIGHTING','TU-1 Age':'AGE_1',
             'TU-1 Sex ':'SEX_1','Injury 00':'INJURY 00','Injury 01':'INJURY 01','Injury 02':'INJURY 02',
             'Injury 03':'INJURY 03','Injury 04':'INJURY 04','TU-1 Driver Action':'VIOLCODE_1','Location':'LOCATION'}

# %%
data = data.rename(columns= col_rename)

# %%
data_1 = data[useful_cols]

# %%
data_1
# Out:
#        INJURY 00  INJURY 01  INJURY 02  INJURY 03  INJURY 04  AGE_1  \
# 0              5          0          0          0          0     18
# 1              1          0          0          0          0      0
# 2              0          0          0          0          0      0
# 3              0          0          0          0          0      0
# 4              0          0          0          0          0      0
# ...          ...        ...        ...        ...        ...    ...
# 97917          1          0          0          0          0      0
# 97918          1          0          0          0          0     66
# 97919          0          1          1          0          0     54
# 97920          3          0          0          0          0      0
# 97921          0          0          0          0          0      0
#
#                   ROAD_DESC   CONTOUR CONDITION          LIGHTING WEATHER  \
# 0      Intersection Related  Straight     Snowy          Daylight    Snow
# ...

# %%
for i in data_1.columns:
    print(i,'   ',data_1[i].unique(),'\n')
# Out:
# INJURY 00     [ 5  1  0  2  4  3  7 10  8  6 12  9 15 11 13 14 16 33 17 36]
#
# INJURY 01     [ 0  3  1  2  4  6  5  7  9  8 11 33]
#
# INJURY 02     [0 1 2 4 3 5 7 6 8]
#
# INJURY 03     [0 1 2 7 3 5 4 6]
#
# INJURY 04     [0 1 2 3 5 4]
#
# AGE_1     [ 18   0  36  33  30  41  32  34  20  60  16  53  25  27  28  29  43  35
#   22  26  92  55  31  70  17  38  19  48  66  40  24  50  37  23  61  56
#   68  21  47  52  59  39  78  42  69  71  73  49  46  65  67  75  63  57
#   54  87  82  51  64  44  62  58  72  15  89  81  83  84  79  80  74  45
#   86  77  85  90  76  88  91  94  96  14  12  95   7  93  11  97 121  13
#    5 105]
#
# ROAD_DESC     ['Intersection Related' 'Non-Intersection' 'At Intersection'
#  'Crossover-Related ' 'Ramp' 'Driveway Access Related' 'Alley Related'
#  'Parking Lot' 'Ramp-related' 'Roundabout' 'Railroad Crossing Related'
#  'Express/Managed/HOV Lane' nan 'Shared-Use Path or Trail'
#  'Auxiliary Lane' 'Mid-Block Crosswalk']
#
# ...

# %%
data_1.isnull().sum()
# Out:
# INJURY 00         0
# INJURY 01         0
# INJURY 02         0
# INJURY 03         0
# INJURY 04         0
# AGE_1             0
# ROAD_DESC        31
# CONTOUR       39886
# CONDITION       434
# LIGHTING        516
# WEATHER         808
# SEX_1         14008
# SYSTEM            0
# VIOLCODE_1    10497
# LOCATION          1
# dtype: int64

# %%
data_1['SEX_1']
# Out:
# array(['M', 'F', nan, 'U', 'X'], dtype=object)

# %%
nan_count = data_1['SEX_1'].isna().sum()
print("Number of NaN values in SEX_1  is", (nan_count/len(data_1)*100), 'Percent')
# Out:
# Number of NaN values in SEX_1  is 14.305263372888627 Percent

# %%
data_1['SEX_1'] = data_1['SEX_1'].fillna('U')
# Out:
# C:\Users\karan\AppData\Local\Temp\ipykernel_35704\1639098115.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_1['SEX_1'] = data_1['SEX_1'].fillna('U')

# %%
data_1['SEX_1'] = data_1['SEX_1'].replace('X','U')
# Out:
# C:\Users\karan\AppData\Local\Temp\ipykernel_35704\1804836294.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_1['SEX_1'] = data_1['SEX_1'].replace('X','U')

# %%
for i in data_1.columns:
    print(i, 'has',(data_1[i].isnull().sum()/len(data_1))*100,' Percentage\n')
# Out:
# INJURY 00 has 0.0  Percentage
#
# INJURY 01 has 0.0  Percentage
#
# INJURY 02 has 0.0  Percentage
#
# INJURY 03 has 0.0  Percentage
#
# INJURY 04 has 0.0  Percentage
#
# AGE_1 has 0.0  Percentage
#
# ROAD_DESC has 0.0  Percentage
#
# CONTOUR has 0.0  Percentage
#
# CONDITION has 0.0  Percentage
#
# LIGHTING has 0.0  Percentage
#
# WEATHER has 0.0  Percentage
#
# SEX_1 has 0.0  Percentage
#
# SYSTEM has 0.0  Percentage
#
# VIOLCODE_1 has 0.0  Percentage
#
# LOCATION has 0.0  Percentage

# %%
data_1 = data_1.dropna(subset=['CONTOUR'])

# %%
data_1['VIOLCODE_1'].unique()
# Out:
# array(['Careless Driving ', 'Too Fast for Conditions',
#        'No Contributing Action', 'Failed to Yield ROW',
#        'Over-Correcting/ Over-Steering', 'Lane Violation',
#        'Improper Backing',
#        'Other Contributing Action (Describe in Narrative)',
#        'Failed to Stop at Signal', 'Followed Too Closely',
#        'Improper Turn', 'Reckless Driving',
#        'Disregarded Other Device/Sign/Markings',
#        'Improper Passing on Right', 'Impeded Traffic',
#        'Turned from Wrong Lane or Position', 'Disregard Stop Sign',
#        'Speeding', 'Improper Passing on Left', 'Signaling Violation',
#        'Racing', 'Lacking Required Chains'], dtype=object)

# %%
data_1 = data_1.dropna()

# %%
data_1.to_csv('colo_21.csv', index= False)
