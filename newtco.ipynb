# %%
import numpy as np

# %%
import pandas as pd

# %%
t = pd.read_csv('C:/Users/karan/texas_county_year.csv')

# %%
t['STATE'] = 'Texas'

# %%
t['INJURY_COUNT_SUM']
# Out:
# 0       2850
# 1        128
# 2       9934
# 3       1596
# 4      13527
#        ...
# 757        7
# 758        8
# 759       13
# 760        2
# 761        3
# Name: INJURY_COUNT_SUM, Length: 762, dtype: int64

# %%
for i in t.columns:
    print(i)
# Out:
# Crash_ID
# AGE
# GENDER
# COUNTY_FIPS
# COUNTY
# INTERSECTION
# WEATHER
# LIGHTING
# SURFACE
# HUMAN_FACTOR
# ROAD_CLASS
# MEDIANWIDTH
# LANES
# ROADWIDTH
# AADT
# INJURY_OUTCOME
# INJURY_COUNT
# INTOXICATION
# BUFF_DIST
# ORIG_FID
# Shape_Length
# Shape_Area
# AGE_BAND
# AGE 1-21
# AGE 22-30
# AGE 31-65
# AGE 66 and above
# Unknown Age
# GENDER_DESC
# FEMALE
# MALE
# UNKNOWN_GENDER
# INTERSECTION_DESC
# NO_INTERSECTION
# YES_INTERSECTION
# WEATHER_DESC
# BLOWING SAND/SNOW
# CLEAR
# CLOUDY
# FOG
# OTHER_WEATHER
# RAIN
# SEVERE CROSSWINDS
# SLEET/HAIL
# SNOW_WEATHER
# UNKNOWN_WEATHER
# LIGHTING_DESC
# DARK-LIGHTED
# DARK-NOT LIGHTED
# DARK-UNKNOWN LIGHTING
# DAWN
# DAYLIGHT
# DUSK
# OTHER_LIGHT
# UNKNOWN_LIGHT
# SURF_DESC
# DIRT
# DRY
# ICE
# OTHER_SURF
# SLUSH
# SNOW_SURF
# STANDING_WATER
# UNKNOWN_SURF
# WET
# HUMAN_FACTOR_DESC
# IMPAIRMENT
# INATTENTION
# KNOWN_HUMAN_FACTOR
# LANE_CHNG
# NO_FAULT
# SPEEDING
# TAILGATING
# TECH_PARK
# TURNING
# UNKNOWN_HUMAN_FACTOR
# UNSAFE_BACKING
# ...

# %%
o = pd.read_csv('C:/Users/karan/okla_county_year.csv')

# %%
o['STATE'] = 'Oklahoma'

# %%
for i in o.columns:
    print(i)
# Out:
# Join_Count
# TARGET_FID
# Crash_ID
# County_FIP
# COUNTY
# CITY
# LIGHTING_CAT
# WEATHER_CAT
# ROAD_CLASS
# INTOXICATION
# INATTENTION
# SPEEDING
# TEEN_DRIVE
# OLDER_DRIV
# INJURY_COUNT
# INJURY_OUTCOME
# ROUTE_ID
# FROM_MEASU
# TO_MEASURE
# AADT
# MEDIANWIDT
# FUNCTIONAL
# LANES
# ROAD_WIDTH
# MLENGTH
# BUFF_DIST
# ORIG_FID
# Shape_Length
# Shape_Area
# WEATHER_DESC
# BLOWING SAND/SNOW
# CLEAR
# CLOUDY
# FOG
# OTHER
# RAIN
# SEVERE CROSSWINDS
# SLEET/HAIL
# SNOW
# UNKNOWN_WEATHER
# LIGHTING_DESC
# DARK-LIGHTED
# DARK-NOT LIGHTED
# DARK-UNKNOWN LIGHTING
# DAWN
# DAYLIGHT
# DUSK
# OTHER_LIGHT
# UNKNOWN_LIGHT
# ROAD_TYPE_DESC
# CITY STREET
# COUNTY ROAD
# INTERSTATE
# OTHER ROADS
# US & STATE HIGHWAY
# INTOXICATION_DESC
# ALCOHOL
# ALCOHOL, DRUG
# DRUG
# NO INTOXICATION
# INATTENTION_DESC
# NO_INATTENTION
# YES_INATTENTION
# INJURY_DESC
# NO INJURY_OUTCOME
# YES INJURY_OUTCOME
# LANE_COUNT
# LANE 0
# LANE 1
# LANE 10
# LANE 2
# LANE 3
# LANE 4
# LANE 6
# LANE 8
# INJURY_COUNT_SUM
# ...

# %%
c = pd.read_csv('C:/Users/karan/colorado_county_year.csv')

# %%
o.columns
# Out:
# Index(['Join_Count', 'TARGET_FID', 'Crash_ID', 'County_FIP', 'COUNTY', 'CITY',
#        'LIGHTING_CAT', 'WEATHER_CAT', 'ROAD_CLASS', 'INTOXICATION',
#        'INATTENTION', 'SPEEDING', 'TEEN_DRIVE', 'OLDER_DRIV', 'INJURY_COUNT',
#        'INJURY_OUTCOME', 'ROUTE_ID', 'FROM_MEASU', 'TO_MEASURE', 'AADT',
#        'MEDIANWIDT', 'FUNCTIONAL', 'LANES', 'ROAD_WIDTH', 'MLENGTH',
#        'BUFF_DIST', 'ORIG_FID', 'Shape_Length', 'Shape_Area', 'WEATHER_DESC',
#        'BLOWING SAND/SNOW', 'CLEAR', 'CLOUDY', 'FOG', 'OTHER', 'RAIN',
#        'SEVERE CROSSWINDS', 'SLEET/HAIL', 'SNOW', 'UNKNOWN_WEATHER',
#        'LIGHTING_DESC', 'DARK-LIGHTED', 'DARK-NOT LIGHTED',
#        'DARK-UNKNOWN LIGHTING', 'DAWN', 'DAYLIGHT', 'DUSK', 'OTHER_LIGHT',
#        'UNKNOWN_LIGHT', 'ROAD_TYPE_DESC', 'CITY STREET', 'COUNTY ROAD',
#        'INTERSTATE', 'OTHER ROADS', 'US & STATE HIGHWAY', 'INTOXICATION_DESC',
#        'ALCOHOL', 'ALCOHOL, DRUG', 'DRUG', 'NO INTOXICATION',
# ...

# %%
o.rename(columns={'County_FIP':'COUNTY_FIPS'},inplace= True)

# %%
o.rename(columns={'OTHER':'OTHER_WEATHER','SNOW':'SNOW_WEATHER'},inplace= True)

# %%
o.drop(columns=['INATTENTION', 'SPEEDING'],inplace= True)

# %%
o.rename(columns={'YES_INATTENTION':'INATTENTION','YES_SPEEDING':'SPEEDING'},inplace= True)

# %%
o.columns.get_loc('COUNTY ROAD')
# Out:
# 49

# %%
o.insert(50,'FARM TO MARKET',0)

# %%
o.columns.get_loc('OTHER ROADS')
# Out:
# 52

# %%
o.insert(53,'TOLL BRIDGES',0)

# %%
o.columns.get_loc('TOLL BRIDGES')
# Out:
# 53

# %%
o.insert(54,'TOLLWAY',0)

# %%
o.rename(columns={'NO INJURY_OUTCOME':'NO_INJURY','YES INJURY_OUTCOME':'YES_INJURY'},inplace= True)

# %%
o.columns.get_loc('DRUG')
# Out:
# 59

# %%
o.insert(60,'MARIJUANA',0)

# %%
o.columns.get_loc('MARIJUANA')
# Out:
# 60

# %%
o.insert(61,'MEDICINAL',0)

# %%
o.columns
# Out:
# Index(['Join_Count', 'TARGET_FID', 'Crash_ID', 'COUNTY_FIPS', 'COUNTY', 'CITY',
#        'LIGHTING_CAT', 'WEATHER_CAT', 'ROAD_CLASS', 'INTOXICATION',
#        'TEEN_DRIVE', 'OLDER_DRIV', 'INJURY_COUNT', 'INJURY_OUTCOME',
#        'ROUTE_ID', 'FROM_MEASU', 'TO_MEASURE', 'AADT', 'MEDIANWIDT',
#        'FUNCTIONAL', 'LANES', 'ROAD_WIDTH', 'MLENGTH', 'BUFF_DIST', 'ORIG_FID',
#        'Shape_Length', 'Shape_Area', 'WEATHER_DESC', 'BLOWING SAND/SNOW',
#        'CLEAR', 'CLOUDY', 'FOG', 'OTHER_WEATHER', 'RAIN', 'SEVERE CROSSWINDS',
#        'SLEET/HAIL', 'SNOW_WEATHER', 'UNKNOWN_WEATHER', 'LIGHTING_DESC',
#        'DARK-LIGHTED', 'DARK-NOT LIGHTED', 'DARK-UNKNOWN LIGHTING', 'DAWN',
#        'DAYLIGHT', 'DUSK', 'OTHER_LIGHT', 'UNKNOWN_LIGHT', 'ROAD_TYPE_DESC',
#        'CITY STREET', 'COUNTY ROAD', 'FARM TO MARKET', 'INTERSTATE',
#        'OTHER ROADS', 'TOLL BRIDGES', 'TOLLWAY', 'US & STATE HIGHWAY',
#        'INTOXICATION_DESC', 'ALCOHOL', 'ALCOHOL, DRUG', 'DRUG', 'MARIJUANA',
# ...

# %%
col= ['Crash_ID', 'COUNTY_FIPS', 'COUNTY','INJURY_COUNT','INJURY_OUTCOME','INJURY_COUNT_SUM',
     'BLOWING SAND/SNOW',
       'CLEAR', 'CLOUDY', 'FOG', 'OTHER_WEATHER', 'RAIN', 'SEVERE CROSSWINDS',
       'SLEET/HAIL', 'SNOW_WEATHER', 'UNKNOWN_WEATHER','DARK-LIGHTED', 'DARK-NOT LIGHTED', 'DARK-UNKNOWN LIGHTING', 'DAWN',
       'DAYLIGHT', 'DUSK', 'OTHER_LIGHT', 'UNKNOWN_LIGHT','INATTENTION','SPEEDING',
      'CITY STREET', 'COUNTY ROAD', 'FARM TO MARKET', 'INTERSTATE',
       'OTHER ROADS', 'TOLL BRIDGES', 'TOLLWAY', 'US & STATE HIGHWAY','NO_INJURY', 'YES_INJURY',
      'ALCOHOL', 'ALCOHOL, DRUG', 'DRUG', 'MARIJUANA',
       'MEDICINAL', 'NO INTOXICATION','YEAR_CAT', 'YEAR_2019', 'YEAR_2020',
       'YEAR_2021', 'STATE'
      
     ]

# %%
t1 = t[col]

# %%
t1
# Out:
#      Crash_ID  COUNTY_FIPS   COUNTY  INJURY_COUNT  INJURY_OUTCOME  \
# 0    15585669        48141  El Paso             0               0
# 1    16473665        48241   Jasper             1               1
# 2    16585839        48113   Dallas             1               1
# 3    16824710        48303  Lubbock             2               1
# 4    16824789        48201   Harris             0               0
# ..        ...          ...      ...           ...             ...
# 757  18161346        48079  Cochran             0               0
# 758  18163122        48033   Borden             3               1
# 759  18202307        48443  Terrell             0               0
# 760  18208669        48101   Cottle             1               1
# 761  18400394        48269     King             1               1
#
#      INJURY_COUNT_SUM  BLOWING SAND/SNOW       CLEAR     CLOUDY       FOG  \
# 0                2850           0.324254   90.466926   4.824903  0.025940
# ...

# %%
o1 = o[col]

# %%
o1
# Out:
#       Crash_ID  COUNTY_FIPS       COUNTY  INJURY_COUNT  INJURY_OUTCOME  \
# 0    191140536        40143        Tulsa             1               1
# 1    190500504        40145      Wagoner             2               1
# 2    190805245        40119        Payne             1               1
# 3    191285346        40017     Canadian             2               1
# 4    190675822        40047     Garfield             2               1
# ..         ...          ...          ...           ...             ...
# 226  300504729        40067    Jefferson             1               1
# 227  300501977        40129  Roger Mills             0               0
# 228  300511808        40045        Ellis             2               1
# 229  300506547        40057       Harmon             3               1
# 230  300526897        40043        Dewey             1               1
#
#      INJURY_COUNT_SUM  BLOWING SAND/SNOW       CLEAR     CLOUDY       FOG  \
# ...

# %%
ot = pd.concat([t1,o1],axis=0)

# %%
ot
# Out:
#       Crash_ID  COUNTY_FIPS       COUNTY  INJURY_COUNT  INJURY_OUTCOME  \
# 0     15585669        48141      El Paso             0               0
# 1     16473665        48241       Jasper             1               1
# 2     16585839        48113       Dallas             1               1
# 3     16824710        48303      Lubbock             2               1
# 4     16824789        48201       Harris             0               0
# ..         ...          ...          ...           ...             ...
# 226  300504729        40067    Jefferson             1               1
# 227  300501977        40129  Roger Mills             0               0
# 228  300511808        40045        Ellis             2               1
# 229  300506547        40057       Harmon             3               1
# 230  300526897        40043        Dewey             1               1
#
#      INJURY_COUNT_SUM  BLOWING SAND/SNOW       CLEAR     CLOUDY       FOG  \
# ...

# %%
ot.isnull().sum()
# Out:
# Crash_ID                 0
# COUNTY_FIPS              0
# COUNTY                   0
# INJURY_COUNT             0
# INJURY_OUTCOME           0
# BLOWING SAND/SNOW        0
# CLEAR                    0
# CLOUDY                   0
# FOG                      0
# OTHER_WEATHER            0
# RAIN                     0
# SEVERE CROSSWINDS        0
# SLEET/HAIL               0
# SNOW_WEATHER             0
# UNKNOWN_WEATHER          0
# DARK-LIGHTED             0
# DARK-NOT LIGHTED         0
# DARK-UNKNOWN LIGHTING    0
# DAWN                     0
# DAYLIGHT                 0
# DUSK                     0
# OTHER_LIGHT              0
# UNKNOWN_LIGHT            0
# INATTENTION              0
# SPEEDING                 0
# CITY STREET              0
# COUNTY ROAD              0
# FARM TO MARKET           0
# INTERSTATE               0
# OTHER ROADS              0
# TOLL BRIDGES             0
# TOLLWAY                  0
# US & STATE HIGHWAY       0
# NO_INJURY                0
# ...

# %%
ot.columns
# Out:
# Index(['Crash_ID', 'COUNTY_FIPS', 'COUNTY', 'INJURY_COUNT', 'INJURY_OUTCOME',
#        'BLOWING SAND/SNOW', 'CLEAR', 'CLOUDY', 'FOG', 'OTHER_WEATHER', 'RAIN',
#        'SEVERE CROSSWINDS', 'SLEET/HAIL', 'SNOW_WEATHER', 'UNKNOWN_WEATHER',
#        'DARK-LIGHTED', 'DARK-NOT LIGHTED', 'DARK-UNKNOWN LIGHTING', 'DAWN',
#        'DAYLIGHT', 'DUSK', 'OTHER_LIGHT', 'UNKNOWN_LIGHT', 'INATTENTION',
#        'SPEEDING', 'CITY STREET', 'COUNTY ROAD', 'FARM TO MARKET',
#        'INTERSTATE', 'OTHER ROADS', 'TOLL BRIDGES', 'TOLLWAY',
#        'US & STATE HIGHWAY', 'NO_INJURY', 'YES_INJURY', 'ALCOHOL',
#        'ALCOHOL, DRUG', 'DRUG', 'MARIJUANA', 'MEDICINAL', 'NO INTOXICATION',
#        'YEAR_CAT', 'YEAR_2019', 'YEAR_2020', 'YEAR_2021', 'STATE'],
#       dtype='object')

# %%
c.columns
# Out:
# Index(['ROAD_CLASS', 'INTERSECTION', 'CONTOUR', 'SURFACE', 'LIGHTING',
#        'WEATHER', 'HUMAN_FACTOR', 'INTOXICATION', 'AGE', 'GENDER',
#        'COUNTY_FIPS', 'COUNTY', 'INJURY_COUNT', 'INJURY_OUTCOME', 'Crash_ID',
#        'BUFF_DIST', 'ORIG_FID', 'Shape_Length', 'Shape_Area', 'WEATHER_DESC',
#        'BLOWING SAND/SNOW', 'CLEAR', 'CLOUDY', 'FOG', 'OTHER_WEATHER', 'RAIN',
#        'SEVERE CROSSWINDS', 'SLEET/HAIL', 'SNOW_WEATHER', 'LIGHTING_DESC',
#        'DARK-LIGHTED', 'DARK-NOT LIGHTED', 'DAWN', 'DAYLIGHT', 'DUSK',
#        'SURF_DESC', 'DIRT', 'DRY', 'ICE', 'SLUSH', 'SNOW_SURF', 'UNKNOWN_SURF',
#        'WET', 'INTOXICATION_DESC', 'ALCOHOL', 'ALCOHOL, DRUG', 'DRUG',
#        'MEDICINAL', 'MARIJUANA', 'NO INTOXICATION', 'INTERSECTION_DESC',
#        'NO_INTERSECTION', 'YES_INTERSECTION', 'ROAD_TYPE_DESC', 'CITY STREET',
#        'COUNTY ROAD', 'INTERSTATE', 'OTHER ROADS', 'US & STATE HIGHWAY',
#        'HUMAN_FACTOR_DESC', 'IMPAIRMENT', 'INATTENTION', 'KNOWN_HUMAN_FACTOR',
# ...

# %%
c['STATE'] = 'Colorado'

# %%
c.columns.get_loc('DARK-NOT LIGHTED')
# Out:
# 31

# %%
c.insert(32,'DARK-UNKNOWN LIGHTING',0)

# %%
c.columns.get_loc('DUSK')
# Out:
# 35

# %%
c.insert(36,'OTHER_LIGHT',0)

# %%
c.columns.get_loc('OTHER_LIGHT')
# Out:
# 36

# %%
c.insert(37,'UNKNOWN_LIGHT',0)

# %%
c.columns.get_loc('COUNTY ROAD')
# Out:
# 58

# %%
c.insert(59,'FARM TO MARKET',0)

# %%
c.columns.get_loc('OTHER ROADS')
# Out:
# 61

# %%
c.insert(62,'TOLL BRIDGES',0)

# %%
c.columns.get_loc('TOLL BRIDGES')
# Out:
# 62

# %%
c.insert(63,'TOLLWAY',0)

# %%
c.rename(columns={'NO INJURY_OUTCOME':'NO_INJURY','YES INJURY_OUTCOME':'YES_INJURY'},inplace= True)

# %%
cols = ['Crash_ID', 'COUNTY_FIPS', 'COUNTY','INJURY_COUNT','INJURY_OUTCOME','INJURY_COUNT_SUM',
     'BLOWING SAND/SNOW',
       'CLEAR', 'CLOUDY', 'FOG', 'OTHER_WEATHER', 'RAIN', 'SEVERE CROSSWINDS',
       'SLEET/HAIL', 'SNOW_WEATHER', 'UNKNOWN_WEATHER','DARK-LIGHTED', 'DARK-NOT LIGHTED', 'DARK-UNKNOWN LIGHTING', 'DAWN',
       'DAYLIGHT', 'DUSK', 'OTHER_LIGHT', 'UNKNOWN_LIGHT','INATTENTION','SPEEDING',
      'CITY STREET', 'COUNTY ROAD', 'FARM TO MARKET', 'INTERSTATE',
       'OTHER ROADS', 'TOLL BRIDGES', 'TOLLWAY', 'US & STATE HIGHWAY','NO_INJURY', 'YES_INJURY',
      'ALCOHOL', 'ALCOHOL, DRUG', 'DRUG', 'MARIJUANA',
       'MEDICINAL', 'NO INTOXICATION','YEAR_CAT', 'YEAR_2019', 'YEAR_2020',
       'YEAR_2021', 'STATE']

# %%
ot1 =ot[cols]

# %%
ot1
# Out:
#       Crash_ID  COUNTY_FIPS       COUNTY  INJURY_COUNT  INJURY_OUTCOME  \
# 0     15585669        48141      El Paso             0               0
# 1     16473665        48241       Jasper             1               1
# 2     16585839        48113       Dallas             1               1
# 3     16824710        48303      Lubbock             2               1
# 4     16824789        48201       Harris             0               0
# ..         ...          ...          ...           ...             ...
# 226  300504729        40067    Jefferson             1               1
# 227  300501977        40129  Roger Mills             0               0
# 228  300511808        40045        Ellis             2               1
# 229  300506547        40057       Harmon             3               1
# 230  300526897        40043        Dewey             1               1
#
#      INJURY_COUNT_SUM  BLOWING SAND/SNOW       CLEAR     CLOUDY       FOG  \
# ...

# %%
c1 = c[cols]
c1
# Out:
#      Crash_ID  COUNTY_FIPS      COUNTY  INJURY_COUNT  INJURY_OUTCOME  \
# 0    10000002         8001       ADAMS             0               0
# 1    10000003         8059   JEFFERSON             1               1
# 2    10000005         8031      DENVER             0               0
# 3    10000010         8037       EAGLE             0               0
# 4    10000011         8041     EL PASO             0               0
# ..        ...          ...         ...           ...             ...
# 187  10212672         8103  RIO BLANCO             2               1
# 188  10214252         8009        BACA             0               0
# 189  10214428         8065        LAKE             1               1
# 190  10215666         8017    CHEYENNE             1               1
# 191  10221660         8115    SEDGWICK             0               0
#
#      INJURY_COUNT_SUM  BLOWING SAND/SNOW       CLEAR     CLOUDY       FOG  \
# ...

# %%
c.columns.get_loc('SNOW_WEATHER')
# Out:
# 28

# %%
c.insert(29,'UNKNOWN_WEATHER',0)

# %%
cto = pd.concat([ot1,c1],axis=0)

# %%
cto.to_csv('Oklahoma_texas_colorado.csv',index= False)

# %%
t = pd.read_csv('C:/Users/karan/tco_pop.csv')

# %%
t.isna().sum()
# Out:
# POPULATION    6
# Crash_ID      0
# dtype: int64
