# %%
import numpy as np
import pandas as pd

# %%
colo = pd.read_csv('C:/Users/karan/colorado_final_merged.csv')
# Out:
# C:\Users\karan\AppData\Local\Temp\ipykernel_29356\542511300.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   colo = pd.read_csv('C:/Users/karan/colorado_final_merged.csv')

# %%
colo.columns
# Out:
# Index(['ROAD_CLASS', 'DATE', 'TIME', 'INTERSECTION', 'CONTOUR', 'SURFACE',
#        'LIGHTING', 'WEATHER', 'HUMAN_FACTOR', 'INTOXICATION', 'AGE', 'GENDER',
#        'COUNTY_FIPS', 'COUNTY', 'LATITUDE', 'LONGITUDE', 'INJURY_COUNT',
#        'INJURY_OUTCOME', 'Crash_ID', 'BUFF_DIST', 'ORIG_FID', 'Shape_Length',
#        'Shape_Area', 'WEATHER_DESC', 'BLOWING SAND/SNOW', 'CLEAR', 'CLOUDY',
#        'FOG', 'OTHER_WEATHER', 'RAIN', 'SEVERE CROSSWINDS', 'SLEET/HAIL',
#        'SNOW_WEATHER', 'LIGHTING_DESC', 'DARK-LIGHTED', 'DARK-NOT LIGHTED',
#        'DAWN', 'DAYLIGHT', 'DUSK', 'SURF_DESC', 'DIRT', 'DRY', 'ICE', 'SLUSH',
#        'SNOW_SURF', 'UNKNOWN_SURF', 'WET', 'INTOXICATION_DESC', 'ALCOHOL',
#        'ALCOHOL, DRUG', 'DRUG', 'MEDICINAL', 'MARIJUANA', 'NO INTOXICATION',
#        'INTERSECTION_DESC', 'NO_INTERSECTION', 'YES_INTERSECTION',
#        'ROAD_TYPE_DESC', 'CITY STREET', 'COUNTY ROAD', 'INTERSTATE',
# ...

# %%
colo.shape
# Out:
# (217290, 94)

# %%
colo['LATITUDE']
# Out:
# 0         39.854790
# 1         39.778123
# 2         39.772864
# 3         39.729087
# 4         39.830698
#             ...
# 217285    39.972348
# 217286    39.605230
# 217287    39.695930
# 217288    40.422650
# 217289    39.830140
# Name: LATITUDE, Length: 217290, dtype: float64

# %%
colo['State'] = 'Colorado'

# %%
colo.columns
# Out:
# Index(['ROAD_CLASS', 'DATE', 'TIME', 'INTERSECTION', 'CONTOUR', 'SURFACE',
#        'LIGHTING', 'WEATHER', 'HUMAN_FACTOR', 'INTOXICATION', 'AGE', 'GENDER',
#        'COUNTY_FIPS', 'COUNTY', 'LATITUDE', 'LONGITUDE', 'INJURY_COUNT',
#        'INJURY_OUTCOME', 'Crash_ID', 'BUFF_DIST', 'ORIG_FID', 'Shape_Length',
#        'Shape_Area', 'WEATHER_DESC', 'BLOWING SAND/SNOW', 'CLEAR', 'CLOUDY',
#        'FOG', 'OTHER_WEATHER', 'RAIN', 'SEVERE CROSSWINDS', 'SLEET/HAIL',
#        'SNOW_WEATHER', 'LIGHTING_DESC', 'DARK-LIGHTED', 'DARK-NOT LIGHTED',
#        'DAWN', 'DAYLIGHT', 'DUSK', 'SURF_DESC', 'DIRT', 'DRY', 'ICE', 'SLUSH',
#        'SNOW_SURF', 'UNKNOWN_SURF', 'WET', 'INTOXICATION_DESC', 'ALCOHOL',
#        'ALCOHOL, DRUG', 'DRUG', 'MEDICINAL', 'MARIJUANA', 'NO INTOXICATION',
#        'INTERSECTION_DESC', 'NO_INTERSECTION', 'YES_INTERSECTION',
#        'ROAD_TYPE_DESC', 'CITY STREET', 'COUNTY ROAD', 'INTERSTATE',
# ...

# %%
colo['YEAR_2019'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
colo.rename(columns={'State':'STATE'},inplace= True)

# %%
colo_19 = colo[colo['YEAR_2019']==1]

# %%
colo_20 = colo[colo['YEAR_2020']==1]

# %%
colo_21 = colo[colo['YEAR_2021']==1]

# %%
colo_19.drop(columns=['LATITUDE','LONGITUDE','DATE','TIME'],inplace= True)
# Out:
# C:\Users\karan\AppData\Local\Temp\ipykernel_29356\1359765722.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   colo_19.drop(columns=['LATITUDE','LONGITUDE','DATE','TIME'],inplace= True)

# %%
colo_20.drop(columns=['LATITUDE','LONGITUDE','DATE','TIME'],inplace= True)
# Out:
# C:\Users\karan\AppData\Local\Temp\ipykernel_29356\3780686419.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   colo_20.drop(columns=['LATITUDE','LONGITUDE','DATE','TIME'],inplace= True)

# %%
colo_21.drop(columns=['LATITUDE','LONGITUDE','DATE','TIME'],inplace= True)
# Out:
# C:\Users\karan\AppData\Local\Temp\ipykernel_29356\2211545786.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   colo_21.drop(columns=['LATITUDE','LONGITUDE','DATE','TIME'],inplace= True)

# %%
colo['COUNTY'].drop_duplicates(keep='')
# Out:
# 64

# %%
colo_2019 = colo_19.drop_duplicates(subset=['COUNTY'],keep='first')

# %%
colo_2019
# Out:
#       ROAD_CLASS  INTERSECTION            CONTOUR  SURFACE  LIGHTING  WEATHER  \
# 0              1             0  STRAIGHT ON-GRADE        9         4        4
# 1              5             0  STRAIGHT ON-LEVEL        6         4        4
# 3              5             1  STRAIGHT ON-LEVEL        6         4        4
# 7              2             0     CURVE ON-GRADE        9         3        4
# 8              5             0     CURVE ON-LEVEL        6         4        8
# ...          ...           ...                ...      ...       ...      ...
# 3544           2             0  STRAIGHT ON-LEVEL        1         1        5
# 4537           2             0  STRAIGHT ON-LEVEL        1         3        8
# 5213           2             0  STRAIGHT ON-LEVEL        6         3        7
# 5235           2             0  STRAIGHT ON-GRADE        6         3        4
# 8310           1             0  STRAIGHT ON-GRADE        1         3        8
#
# ...

# %%
colo_20.shape
# Out:
# (74059, 91)

# %%
colo_2020 = colo_20.drop_duplicates(subset=['COUNTY'],keep='first')

# %%
colo_2021 = colo_21.drop_duplicates(subset=['COUNTY'],keep='first')

# %%
colo_2019.shape, colo_2020.shape, colo_2021.shape
# Out:
# ((64, 91), (64, 91), (64, 91))

# %%
colorado_all = pd.concat([colo_2019,colo_2020,colo_2021], axis=0)

# %%
colo_2019
# Out:
#       ROAD_CLASS  INTERSECTION            CONTOUR  SURFACE  LIGHTING  WEATHER  \
# 0              1             0  STRAIGHT ON-GRADE        9         4        4
# 1              5             0  STRAIGHT ON-LEVEL        6         4        4
# 3              5             1  STRAIGHT ON-LEVEL        6         4        4
# 7              2             0     CURVE ON-GRADE        9         3        4
# 8              5             0     CURVE ON-LEVEL        6         4        8
# ...          ...           ...                ...      ...       ...      ...
# 3544           2             0  STRAIGHT ON-LEVEL        1         1        5
# 4537           2             0  STRAIGHT ON-LEVEL        1         3        8
# 5213           2             0  STRAIGHT ON-LEVEL        6         3        7
# 5235           2             0  STRAIGHT ON-GRADE        6         3        4
# 8310           1             0  STRAIGHT ON-GRADE        1         3        8
#
# ...

# %%
colorado_all.shape
# Out:
# (192, 91)

# %%
colo_2019.to_csv('colo_2019_county.csv',index= False)

# %%
colo_20.to_csv('colo_2020_county.csv',index= False)

# %%
colo_2021.to_csv('colo_2021_county.csv',index= False)

# %%
colorado_all.to_csv('colorado_county_year.csv',index= False)
