# %%
import numpy as np
import pandas as pd

# %%
colo_2021 = pd.read_excel('C:/Texas/2021_CRASH_COLORADO_FIPS_INCLUDED.xlsx')

# %%
cat_columns = [i for i in colo_2021.columns if colo_2021[i].dtype == 'object']

# %%
cat_columns
# Out:
# ['SYSTEM',
#  'TIME',
#  'Agency Id',
#  'City',
#  'County',
#  'Location 1',
#  'Link',
#  'Location 2',
#  'Location',
#  'Road Description',
#  'First HE',
#  'Second HE',
#  'Third HE',
#  'Fourth HE',
#  'MHE',
#  'Crash Type',
#  'Wild Animal',
#  'Road Contour Curves',
#  'Road Contour Grade',
#  'Road Condition',
#  'Lighting Conditions',
#  'Weather Condition',
#  'Lane Position',
#  'TU-1 Direction',
#  'TU-2 Direction',
#  'TU-1 Movement',
#  'TU-2 Movement',
#  'TU-1 Type',
#  'TU-2 Type',
#  'TU-1 Driver Action',
#  'TU-2 Driver Action',
#  'TU-1 Human Contributing Factor',
#  'TU-2 Human Contributing Factor',
#  'TU-1 Sex ',
#  'TU-2 Sex',
#  'TU-1 Alcohol Suspected',
#  'TU-2 Alcohol Suspected',
#  'TU-1  Marijuana Suspected',
#  'TU-2 Marijuana Suspected',
#  'TU-1 Other Drugs Suspected ',
#  'TU-2 Other Drugs Suspected ',
#  'TU-1 NM Location ',
#  'TU-2 NM Location ',
#  'TU-1 NM Type',
#  'TU-2 NM Type',
#  'TU-1 NM Sex ',
#  'TU-2 NM Sex ',
#  'TU-1 NM Action ',
# ...

# %%
for i in cat_columns:
    print(i, colo_2021[i].unique(),'\n')
# Out:
# SYSTEM ['State Highway' 'County Road' 'City Street' 'Interstate Highway'
#  'Frontage Road']
#
# TIME ['00:00:00' '00:05:00' '00:17:00' ... '04:34:00' '03:09:00' '03:33:00']
#
# Agency Id ['GLWDSPGPD' 'CSP' 'WMPD' 'DPD' 'CSPD' 'AURPD' 'GJPD' 'DGOPD' 'RTTSO'
#  'PUPD' 'LVPD' 'VPD' 'SBTSGPD' 'CMCPD' 'LPD' 'CHVPD' 'LTPD' 'DACOPD' 'NPD'
#  'BKPD' 'ALPD' 'CRTPZ' 'LFTTPD' 'EVNPD' 'ASO' 'ARVPD' 'FLPD' 'FTMGNPD'
#  'FTCPD' 'BRPD' 'ASPD' 'FHPD' 'GDNPD' 'JPD' 'DSO' 'BFPD' 'GRYPD' 'LNTRPD'
#  'LAJTPD' 'CNPD' 'GVPD' 'GNPD' 'WLDSO' 'SVPD' 'WRPD' 'BLDPD' 'ATPD' 'PPD'
#  'THPD' 'CRPD' 'STPD' 'CBNVPD' 'FDRKPD' 'LMRPD' 'EGLWD PD' 'LDPS' 'MTPD'
#  'TNTHPD' 'CUSO' 'MMTPD' 'ESO' 'FTTAPD' 'RFLPD' 'BVPD' 'PUSO' 'WDSPD'
#  'DLLPD' 'SMVLGPD' 'PSO' 'GLPNSO' 'LCBPD' 'MPD' 'EMPREPD' 'TPD' 'DTPD'
#  'FLWSCPD' 'NCPD' 'LUPD' 'EPPD' 'ERPD' 'LRMSO' 'JKSNSO' 'FRSWNTPPD' 'BPD'
#  'SDPD' 'FNTN PD' 'BRSPD' 'FRSTPD' 'LKSO' 'GRBYPD' 'BAMO' 'RFPD' nan
# ...
